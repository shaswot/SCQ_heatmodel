# %%
import sys
import git
import pathlib

# Set up the PROJ_ROOT variable
PROJ_ROOT_PATH = pathlib.Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
PROJ_ROOT =  str(PROJ_ROOT_PATH)
if PROJ_ROOT not in sys.path:
    sys.path.append(PROJ_ROOT)

# Explicitly add the current notebook's directory
CURRENT_DIR = str(pathlib.Path().absolute())
if CURRENT_DIR not in sys.path:
    sys.path.insert(0, CURRENT_DIR)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors
# %matplotlib inline  

import yaml

# %%
from library.fridges import TEMP_STAGES, FRIDGE_LIBRARY
FRIDGE_NAME = "KIDE"
fridge = "kide"
cooling_power_budget = FRIDGE_LIBRARY[FRIDGE_NAME]["cooling_power"]
temp_stage = "4K"
QUBIT_GROUP_SIZE = 8

COOLING_POWER = cooling_power_budget[temp_stage]

# %%
def get_amp_hl(fridge, amp, wire):
    exp = "ff-fc-delft-"+ amp + "_" + wire + "-" + fridge
    fname = PROJ_ROOT_PATH / "notebooks" / "experiments" / "solutions" /fridge / amp / exp / f"{exp}.pkl"
    pqfname =  PROJ_ROOT_PATH / "notebooks" / "experiments" / "solutions" / fridge / amp / exp  / f"PQ_{exp}.pkl"
    df =  pd.read_pickle(fname)
    df_pq =  pd.read_pickle(pqfname)
    pq = df_pq.iloc[0].tolist()

    s = df.loc["4K", "AMP_BIAS"]

    phl = s[("PASSIVE", "IDLE")]
    ahl = s[("AMP", "IDLE")]
    if ("AMP_OHMIC", "IDLE") in s.index:
        ohl = s[("AMP_OHMIC", "IDLE")]
    else:
        ohl = 0.0

    NO_OF_QUBIT_GROUPS = int(min(pq)/QUBIT_GROUP_SIZE)

    # Factor of 2 because we need two amplifiers per qubit group
    scale = COOLING_POWER / NO_OF_QUBIT_GROUPS / 2
    phl *= scale
    ahl *= scale
    ohl *= scale

    thl = phl + ahl + ohl

    return phl, ahl, ohl, thl

# %%
_SI_PREFIX = {
    -24: "y", -21: "z", -18: "a", -15: "f", -12: "p", -9: "n",
    -6: "u", -3: "m", 0: "", 3: "k", 6: "M", 9: "G", 12: "T",
    15: "P", 18: "E", 21: "Z", 24: "Y",
}

def fmt_eng(x: float, sig: int = 3, unit: str = "W") -> str:
    """Engineering notation with SI prefix; exponent divisible by 3."""
    x = float(x)
    if x == 0.0 or not np.isfinite(x):
        return f"{x:g}{unit}"

    exp3 = int(np.floor(np.log10(abs(x)) / 3) * 3)
    exp3 = max(min(exp3, 24), -24)  # clamp to known prefixes
    scaled = x / (10 ** exp3)
    prefix = _SI_PREFIX[exp3]

    # sig significant figures, no trailing clutter
    s = f"{scaled:.2f}".rstrip('0').rstrip('.')
    # return rf"\qty{{{s}}}{prefix}{unit}".strip()
    return f"{s} {prefix}{unit}".strip()

# %%
amps  = ["hemt", "hemt-lp", "hemt-ulp", "sisv1"]
wires = ["cu", "mn", "ybco"]

data = {}
for amp in amps:
    row = {}
    for wire in wires:
        phl, ahl, ohl, thl = get_amp_hl(fridge, amp, wire)

        row[wire] = (
            f"AHL: \t {fmt_eng(ahl)}\n"
            f"PHL: \t {fmt_eng(phl)}\n"
            f"OHL: \t {fmt_eng(ohl)}\n"
            f"THL: \t {fmt_eng(thl)}"
        )
    data[amp] = row

df_amp = pd.DataFrame.from_dict(data, orient="index")
df_amp.index.name = "Amplifier"
df_amp.columns.name = "Wire"

# %%
with pd.option_context('display.max_colwidth', None):
    # This CSS property forces the HTML container to respect the \n characters
    display(df_amp.style.set_properties(**{'white-space': 'pre-wrap'}))
# Out:
# <style type="text/css">
# #T_ab79f_row0_col0, #T_ab79f_row0_col1, #T_ab79f_row0_col2, #T_ab79f_row1_col0, #T_ab79f_row1_col1, #T_ab79f_row1_col2, #T_ab79f_row2_col0, #T_ab79f_row2_col1, #T_ab79f_row2_col2, #T_ab79f_row3_col0, #T_ab79f_row3_col1, #T_ab79f_row3_col2 {
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_ab79f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Wire</th>
#       <th id="T_ab79f_level0_col0" class="col_heading level0 col0" >cu</th>
#       <th id="T_ab79f_level0_col1" class="col_heading level0 col1" >mn</th>
#       <th id="T_ab79f_level0_col2" class="col_heading level0 col2" >ybco</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Amplifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab79f_level0_row0" class="row_heading level0 row0" >hemt</th>
#       <td id="T_ab79f_row0_col0" class="data row0 col0" >AHL: 	 7.8 mW
# PHL: 	 22.89 mW
# OHL: 	 440.54 nW
# THL: 	 30.69 mW</td>
#       <td id="T_ab79f_row0_col1" class="data row0 col1" >AHL: 	 7.8 mW
# PHL: 	 95.51 uW
# OHL: 	 468.77 uW
# THL: 	 8.36 mW</td>
#       <td id="T_ab79f_row0_col2" class="data row0 col2" >AHL: 	 7.8 mW
# PHL: 	 11.52 uW
# OHL: 	 0W
# THL: 	 7.81 mW</td>
#     </tr>
#     <tr>
#       <th id="T_ab79f_level0_row1" class="row_heading level0 row1" >hemt-lp</th>
#       <td id="T_ab79f_row1_col0" class="data row1 col0" >AHL: 	 300 uW
# PHL: 	 22.89 mW
# OHL: 	 23.46 nW
# THL: 	 23.19 mW</td>
#       <td id="T_ab79f_row1_col1" class="data row1 col1" >AHL: 	 300 uW
# PHL: 	 95.51 uW
# OHL: 	 24.96 uW
# THL: 	 420.47 uW</td>
#       <td id="T_ab79f_row1_col2" class="data row1 col2" >AHL: 	 300 uW
# PHL: 	 11.52 uW
# OHL: 	 0W
# THL: 	 311.52 uW</td>
#     </tr>
#     <tr>
#       <th id="T_ab79f_level0_row2" class="row_heading level0 row2" >hemt-ulp</th>
#       <td id="T_ab79f_row2_col0" class="data row2 col0" >AHL: 	 200 uW
# PHL: 	 45.77 mW
# OHL: 	 16.29 nW
# THL: 	 45.97 mW</td>
#       <td id="T_ab79f_row2_col1" class="data row2 col1" >AHL: 	 200 uW
# PHL: 	 191.02 uW
# OHL: 	 17.34 uW
# THL: 	 408.35 uW</td>
#       <td id="T_ab79f_row2_col2" class="data row2 col2" >AHL: 	 200 uW
# PHL: 	 23.05 uW
# OHL: 	 0W
# THL: 	 223.05 uW</td>
#     </tr>
#     <tr>
#       <th id="T_ab79f_level0_row3" class="row_heading level0 row3" >sisv1</th>
#       <td id="T_ab79f_row3_col0" class="data row3 col0" >AHL: 	 8.1 uW
# PHL: 	 38.14 mW
# OHL: 	 1.26 uW
# THL: 	 38.15 mW</td>
#       <td id="T_ab79f_row3_col1" class="data row3 col1" >AHL: 	 8.1 uW
# PHL: 	 159.18 uW
# OHL: 	 1.34 mW
# THL: 	 1.51 mW</td>
#       <td id="T_ab79f_row3_col2" class="data row3 col2" >AHL: 	 8.1 uW
# PHL: 	 19.21 uW
# OHL: 	 0W
# THL: 	 27.31 uW</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Special case for sisv1_13w_mn 
fridge = "kide"
amp = "sisv1"
wire = "13w_mn"
phl, ahl, ohl, thl = get_amp_hl(fridge, amp, wire)

print ("For sisv1_13w_mn ")
print(f"AHL: \t {fmt_eng(ahl)}\n"
        f"PHL: \t {fmt_eng(phl)}\n"
        f"OHL: \t {fmt_eng(ohl)}\n"
        f"THL: \t {fmt_eng(thl)}")
# Out:
# For sisv1_13w_mn
# AHL: 	 8.1 uW
# PHL: 	 413.87 uW
# OHL: 	 268.54 uW
# THL: 	 690.51 uW
